# %% [markdown]
# <a href="https://colab.research.google.com/github/akshattjain/MACHINE_LEARNING/blob/main/GridSearchCV_and_RandomizedSearch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn.datasets
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
breast_cancer_dataset = sklearn.datasets.load_breast_cancer()

# %%
df = pd.DataFrame(breast_cancer_dataset.data, columns = breast_cancer_dataset.feature_names)
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
df.shape
# Out:
# (569, 33)

# %%
df['label'] = breast_cancer_dataset.target

# %%
X = df.drop(columns='label', axis=1)
Y = df['label']
print(X)
print(Y)
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
 X = np.asarray(X)
 Y = np.asarray(Y)

# %%
# loading the SVC model
model = SVC()

# %%
# hyperparameters

parameters = {
              'kernel':['linear','poly','rbf','sigmoid'],
              'C':[1, 5, 10, 20]
}

# %%
# grid search
classifier = GridSearchCV(model, parameters, cv=5)

# %%
# fitting the data to our model
classifier.fit(X, Y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [1, 5, 10, 20],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([1.74962106e+00, 3.99947166e-03, 4.88119125e-03, 1.57122612e-02,
#         5.04026980e+00, 6.80508614e-03, 6.74834251e-03, 2.29340076e-02,
#         4.80801873e+00, 7.63859749e-03, 6.94808960e-03, 2.36322880e-02,
#         9.08299646e+00, 4.74352837e-03, 4.35547829e-03, 1.41733646e-02]),
#  'std_fit_time': array([8.35440607e-01, 1.70545594e-04, 1.91468699e-04, 6.64304074e-04,
#         1.07104412e+00, 7.61705094e-04, 2.20068206e-04, 1.47256057e-03,
#         1.58730508e+00, 4.52748297e-04, 5.08076416e-04, 3.64421156e-04,
#         2.44842224e+00, 2.80533736e-04, 1.36058228e-04, 6.52975964e-04]),
#  'mean_score_time': array([0.00129309, 0.00126724, 0.00187368, 0.00413928, 0.00216756,
#         0.00203185, 0.00292974, 0.0061017 , 0.001089  , 0.00227671,
#         0.00274601, 0.0054184 , 0.00132122, 0.00115743, 0.00151544,
#         0.00358915]),
#  'std_score_time': array([1.78811302e-04, 8.73396474e-05, 6.46369257e-05, 2.30206372e-04,
# ...

# %%
# best parameters

best_parameters = classifier.best_params_
print(best_parameters)
# Out:
# {'C': 10, 'kernel': 'linear'}

# %%
# higest accuracy

highest_accuracy = classifier.best_score_
print(highest_accuracy)
# Out:
# 0.9525694767893185

# %%
# loading the results to pandas dataframe
result = pd.DataFrame(classifier.cv_results_)

# %%
result.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       1.749621      0.835441         0.001293        0.000179       1
# 1       0.003999      0.000171         0.001267        0.000087       1
# 2       0.004881      0.000191         0.001874        0.000065       1
# 3       0.015712      0.000664         0.004139        0.000230       1
# 4       5.040270      1.071044         0.002168        0.001740       5
#
#   param_kernel                         params  split0_test_score  \
# 0       linear   {'C': 1, 'kernel': 'linear'}           0.947368
# 1         poly     {'C': 1, 'kernel': 'poly'}           0.842105
# 2          rbf      {'C': 1, 'kernel': 'rbf'}           0.850877
# 3      sigmoid  {'C': 1, 'kernel': 'sigmoid'}           0.543860
# 4       linear   {'C': 5, 'kernel': 'linear'}           0.947368
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# ...

# %%
grid_search_result = result[['param_C','param_kernel','mean_test_score']]

# %%
grid_search_result
# Out:
#    param_C param_kernel  mean_test_score
# 0        1       linear         0.945536
# 1        1         poly         0.908663
# 2        1          rbf         0.912172
# 3        1      sigmoid         0.460441
# 4        5       linear         0.950815
# 5        5         poly         0.922729
# 6        5          rbf         0.931501
# 7        5      sigmoid         0.411178
# 8       10       linear         0.952569
# 9       10         poly         0.920975
# 10      10          rbf         0.922714
# 11      10      sigmoid         0.402391
# 12      20       linear         0.949061
# 13      20         poly         0.919221
# 14      20          rbf         0.920944
# 15      20      sigmoid         0.398867

# %%
# loading the SVC model
model = SVC()

# %%
# hyperparameters

parameters = {
              'kernel':['linear','poly','rbf','sigmoid'],
              'C':[1, 5, 10, 20]
}

# %%
# grid search
classifier = RandomizedSearchCV(model, parameters, cv=5)

# %%
# fitting the data to our model
classifier.fit(X, Y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(),
#                    param_distributions={'C': [1, 5, 10, 20],
#                                         'kernel': ['linear', 'poly', 'rbf',
#                                                    'sigmoid']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([9.25251031e+00, 7.94124603e-03, 2.27308273e-02, 2.53907681e-02,
#         1.47434111e+00, 4.82934198e+00, 4.86011505e-03, 1.42034531e-02,
#         4.76274490e-03, 4.45146561e-03]),
#  'std_fit_time': array([3.32600624e+00, 4.75108255e-04, 1.50549912e-03, 1.58327017e-03,
#         5.03756210e-01, 1.13764758e+00, 1.35060739e-04, 6.71299179e-04,
#         6.75667428e-04, 4.20815706e-04]),
#  'mean_score_time': array([0.00241237, 0.00225935, 0.00578756, 0.00671716, 0.00112562,
#         0.00122614, 0.00184479, 0.00360417, 0.00120034, 0.00168142]),
#  'std_score_time': array([2.32201350e-03, 5.22273442e-04, 3.55874768e-04, 1.16029213e-03,
#         2.40561393e-05, 3.12915548e-04, 6.89811494e-05, 5.14959847e-05,
#         4.44057020e-05, 1.43104909e-04]),
#  'param_kernel': masked_array(data=['linear', 'poly', 'sigmoid', 'sigmoid', 'linear',
#                     'linear', 'rbf', 'sigmoid', 'poly', 'rbf'],
# ...

# %%
# best parameters

best_parameters = classifier.best_params_
print(best_parameters)
# Out:
# {'kernel': 'linear', 'C': 10}

# %%
# higest accuracy

highest_accuracy = classifier.best_score_
print(highest_accuracy)
# Out:
# 0.9525694767893185

# %%
# loading the results to pandas dataframe
result = pd.DataFrame(classifier.cv_results_)

# %%
randomized_search_result = result[['param_C','param_kernel','mean_test_score']]

# %%
randomized_search_result
# Out:
#   param_C param_kernel  mean_test_score
# 0      20       linear         0.949061
# 1      20         poly         0.919221
# 2       5      sigmoid         0.411178
# 3       1      sigmoid         0.460441
# 4       1       linear         0.945536
# 5      10       linear         0.952569
# 6       1          rbf         0.912172
# 7      20      sigmoid         0.398867
# 8      10         poly         0.920975
# 9       5          rbf         0.931501
